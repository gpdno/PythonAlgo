# %%
import pandas as pd

# %%
df_stock = pd.read_csv('america_2019-03-12.csv')

# %%
df_stock.head()
# Out:
#   Ticker     Last  Change %  Change      Rating    Volume  \
# 0   MSFT   112.83  2.099358    2.32         Buy  26490852
# 1   AAPL   178.90  3.464230    5.99         Buy  32004148
# 2   GOOG  1175.76  2.785208   31.86  Strong Buy   1719099
# 3  GOOGL  1179.26  2.547023   29.29  Strong Buy   1501445
# 4   AMZN  1670.88  3.089832   50.08         Buy   3757008
#
#    Market Capitalization  Price to Earnings Ratio (TTM)  Basic EPS (TTM)  \
# 0           847856340000                       25.70287          4.35056
# 1           820526800000                       14.48792         12.03849
# 2           799443500000                       26.31432         44.21324
# 3           799443500000                       26.31432         44.21324
# 4           796141600000                       81.72003         20.34462
#
#    Number of Employees              Sector
# 0             131000.0          Technology
# 1             132000.0          Technology
# 2              98771.0          Technology
# ...

# %%
df_options = pd.read_csv('cboesymboldir2.csv')

# %%
df_options.head()
# Out:
#   Ticker Unnamed: 1  Unnamed: 2  Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# 0      A        SIG         2.0         NaN        NaN          Y          Y
# 1     AA    CITADEL         1.0         NaN        NaN          Y          Y
# 2   AABA        SIG         1.0         NaN        NaN          Y          Y
# 3    AAC  WOLVERINE         3.0         NaN        NaN        NaN        NaN
# 4    AAL        SIG         2.0         NaN          Y          Y          Y
#
#   Unnamed: 7  Unnamed: 8
# 0          L          12
# 1        L-W          25
# 2        L-W          14
# 3        NaN          24
# 4        L-W          15

# %%
merged_df = df_stock.merge(df_options, how = 'inner', on = ['Ticker'])

# %%
merged_df.head()
# Out:
#   Ticker     Last  Change %  Change      Rating    Volume  \
# 0   MSFT   112.83  2.099358    2.32         Buy  26490852
# 1   AAPL   178.90  3.464230    5.99         Buy  32004148
# 2   GOOG  1175.76  2.785208   31.86  Strong Buy   1719099
# 3  GOOGL  1179.26  2.547023   29.29  Strong Buy   1501445
# 4   AMZN  1670.88  3.089832   50.08         Buy   3757008
#
#    Market Capitalization  Price to Earnings Ratio (TTM)  Basic EPS (TTM)  \
# 0           847856340000                       25.70287          4.35056
# 1           820526800000                       14.48792         12.03849
# 2           799443500000                       26.31432         44.21324
# 3           799443500000                       26.31432         44.21324
# 4           796141600000                       81.72003         20.34462
#
#    Number of Employees              Sector Unnamed: 1  Unnamed: 2  Unnamed: 3  \
# 0             131000.0          Technology        SIG         1.0         NaN
# ...

# %%
merged_df.to_csv('Stock_List.csv')

# %%
merged_df.index.max()
# Out:
# 501
